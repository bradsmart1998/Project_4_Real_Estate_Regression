# %%
# Import Dependancies 
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## The Dataset

# %%
# Load in the data from the CSV
csv_file = "Data/all_perth_310121.csv"
housing_df = pd.read_csv(csv_file)
# Display the dataset
housing_df
# Out:
#                   ADDRESS           SUBURB    PRICE  BEDROOMS  BATHROOMS  \
# 0           1 Acorn Place       South Lake   565000         4          2
# 1             1 Addis Way            Wandi   365000         3          2
# 2         1 Ainsley Court          Camillo   287000         3          1
# 3         1 Albert Street         Bellevue   255000         2          1
# 4            1 Aman Place        Lockridge   325000         4          1
# ...                   ...              ...      ...       ...        ...
# 33651      9C Gold Street  South Fremantle  1040000         4          3
# 33652      9C Pycombe Way      Westminster   410000         3          2
# 33653      9D Pycombe Way      Westminster   427000         3          2
# 33654     9D Shalford Way       Girrawheen   295000         3          1
# 33655  9E Margaret Street          Midland   295000         3          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
housing_df["POSTCODE"].value_counts()
# Out:
# 6056    1820
# 6065    1541
# 6164    1270
# 6112    1258
# 6167     973
#         ...
# 6033      21
# 6004      11
# 6126       9
# 6165       7
# 6106       1
# Name: POSTCODE, Length: 114, dtype: int64

# %%
postcode_df = pd.DataFrame(housing_df["POSTCODE"].value_counts().index)

# %%
postcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       114 non-null    int64
# dtypes: int64(1)
# memory usage: 1.0 KB

# %%
postcode_df["kelli"] = "Awesome"
postcode_df.head()
# Out:
#       0    kelli
# 0  6056  Awesome
# 1  6065  Awesome
# 2  6164  Awesome
# 3  6112  Awesome
# 4  6167  Awesome

# %% [markdown]
# ## Explore the data

# %%
# The info on the dataset
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33656 entries, 0 to 33655
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ADDRESS           33656 non-null  object
#  1   SUBURB            33656 non-null  object
#  2   PRICE             33656 non-null  int64
#  3   BEDROOMS          33656 non-null  int64
#  4   BATHROOMS         33656 non-null  int64
#  5   GARAGE            31178 non-null  float64
#  6   LAND_AREA         33656 non-null  int64
#  7   FLOOR_AREA        33656 non-null  int64
#  8   BUILD_YEAR        30501 non-null  float64
#  9   CBD_DIST          33656 non-null  int64
#  10  NEAREST_STN       33656 non-null  object
#  11  NEAREST_STN_DIST  33656 non-null  int64
#  12  DATE_SOLD         33656 non-null  object
#  13  POSTCODE          33656 non-null  int64
#  14  LATITUDE          33656 non-null  float64
#  15  LONGITUDE         33656 non-null  float64
# ...

# %%
# Describe the dataset
housing_df.describe().T
# Out:
#                     count           mean            std           min  \
# PRICE             33656.0  637072.005794  355825.632737  51000.000000
# BEDROOMS          33656.0       3.659110       0.752038      1.000000
# BATHROOMS         33656.0       1.823063       0.587427      1.000000
# GARAGE            31178.0       2.199917       1.365225      1.000000
# LAND_AREA         33656.0    2740.644016   16693.513215     61.000000
# FLOOR_AREA        33656.0     183.501545      72.102982      1.000000
# BUILD_YEAR        30501.0    1989.706436      20.964330   1868.000000
# CBD_DIST          33656.0   19777.374465   11364.415413    681.000000
# NEAREST_STN_DIST  33656.0    4523.371494    4495.064024     46.000000
# POSTCODE          33656.0    6089.420074      62.167921   6003.000000
# LATITUDE          33656.0     -31.960664       0.177780    -32.472979
# LONGITUDE         33656.0     115.879265       0.118137    115.582730
# ...

# %%
# The shape of the dataset
housing_df.shape
# Out:
# (33656, 19)

# %%
# Count the number of null values
housing_df.isnull().sum()
# Out:
# ADDRESS                 0
# SUBURB                  0
# PRICE                   0
# BEDROOMS                0
# BATHROOMS               0
# GARAGE               2478
# LAND_AREA               0
# FLOOR_AREA              0
# BUILD_YEAR           3155
# CBD_DIST                0
# NEAREST_STN             0
# NEAREST_STN_DIST        0
# DATE_SOLD               0
# POSTCODE                0
# LATITUDE                0
# LONGITUDE               0
# NEAREST_SCH             0
# NEAREST_SCH_DIST        0
# NEAREST_SCH_RANK    10952
# dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### Address

# %% [markdown]
# ### Suburb

# %% [markdown]
# ### Price

# %% [markdown]
# ### Bedrooms

# %% [markdown]
# ### Garage

# %% [markdown]
# ### Land Area

# %% [markdown]
# ### Floor Area

# %% [markdown]
# ### Build Year

# %% [markdown]
# ### CBD Dist

# %% [markdown]
# ### Nearest Stn

# %% [markdown]
# ### Nearest Stn Dist

# %% [markdown]
# ### Date Sold

# %% [markdown]
# ### Post Code

# %% [markdown]
# ### Latitude

# %% [markdown]
# ### Longitude

# %% [markdown]
# ## Nearest School

# %%
#group the suburbs
nearest_sch = housing_df.groupby('SUBURB')
nearest_sch

# %%
#view the first few
nearest_sch.first()
# Out:
#                                 ADDRESS    PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# SUBURB
# Alexander Heights        1 Cannon Court   530000         3          2     4.0
# Alfred Cove        10 Clydesdale Street   855000         4          2     2.0
# Alkimos                    1 Point Link   595000         4          2     2.0
# Anketell                 11 Miyak Court  1250000         4          2     2.0
# Applecross             1 Macdonald Road   990000         3          1     4.0
# ...                                 ...      ...       ...        ...     ...
# Wooroloo              10 Clayden Street   358000         4          1     1.0
# Wungong               119 Eleventh Road   679000         6          2    10.0
# Yanchep                   10 Biara Road   272000         3          2     2.0
# Yangebup                  1 Giudice Way   885000         4          2     2.0
# Yokine                 1 Thurlow Avenue   525000         3          1     1.0
#
# ...

# %%
#replace NaN value with 0
replace_nan_rank = housing_df['NEAREST_SCH_RANK'] = housing_df['NEAREST_SCH_RANK'].fillna(0)

# %%
replace_nan_rank
# Out:
# 0          0.0
# 1        129.0
# 2        113.0
# 3          0.0
# 4          0.0
#          ...
# 33651     49.0
# 33652     35.0
# 33653     35.0
# 33654      0.0
# 33655     53.0
# Name: NEAREST_SCH_RANK, Length: 33656, dtype: float64

# %%
mean_rank = housing_df.groupby(['SUBURB']).agg({'NEAREST_SCH_RANK':'mean'})
mean_rank
# Out:
#                    NEAREST_SCH_RANK
# SUBURB
# Alexander Heights         65.772727
# Alfred Cove               48.625000
# Alkimos                   39.000000
# Anketell                        NaN
# Applecross                37.974684
# ...                             ...
# Wooroloo                 105.000000
# Wungong                         NaN
# Yanchep                         NaN
# Yangebup                        NaN
# Yokine                    32.000000
#
# [321 rows x 1 columns]

# %%
#replace NaN value with 0
replace_nan = mean_rank['NEAREST_SCH_RANK'] = mean_rank['NEAREST_SCH_RANK'].fillna(0)

# %%
replace_nan.sort_values()
# Out:
# SUBURB
# Keysbrook          0.0
# Leda               0.0
# Casuarina          0.0
# Bedfordale         0.0
# Beechboro          0.0
#                  ...
# Naval Base       138.0
# Orelia           138.0
# Medina           138.0
# Seville Grove    139.0
# Haynes           139.0
# Name: NEAREST_SCH_RANK, Length: 321, dtype: float64

# %%
# # Create a bar chart based on NaN values with 0
rank_chart = replace_nan.plot(kind='bar', figsize=(15,8))

# # Set the xlabel and ylabel using class methods
rank_chart.set_xlabel("Suburb")
rank_chart.set_ylabel("School Rank")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xn/zsfqtzcx4t9dbvmg4mq2kb640000gn/T/ipykernel_644/1965221121.py in <module>
#       6 rank_chart.set_ylabel("School Rank")
#       7
# ----> 8 plt.show()
#       9 plt.tight_layout()
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     220         if name in props:
#     221             return props[name].__get__(instance)
# --> 222         raise AttributeError(
#     223             f"module {cls.__module__!r} has no attribute {name!r}")
#     224
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
#drop NaN values from each row 
mean_rank.dropna(subset=['NEAREST_SCH_RANK'])
# Out:
#                    NEAREST_SCH_RANK
# SUBURB
# Alexander Heights         65.772727
# Alfred Cove               48.625000
# Alkimos                   39.000000
# Applecross                37.974684
# Ardross                   34.000000
# ...                             ...
# Woodbridge               130.000000
# Woodlands                 13.272727
# Woodvale                  78.705263
# Wooroloo                 105.000000
# Yokine                    32.000000
#
# [279 rows x 1 columns]

# %%
# # Create a bar chart based on with no NaN values
rank_chart = mean_rank.plot(kind='bar', figsize=(15,8))

# # Set the xlabel and ylabel using class methods
rank_chart.set_xlabel("Suburb")
rank_chart.set_ylabel("School Rank")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xn/zsfqtzcx4t9dbvmg4mq2kb640000gn/T/ipykernel_644/1575828351.py in <module>
#       6 rank_chart.set_ylabel("School Rank")
#       7
# ----> 8 plt.show()
#       9 plt.tight_layout()
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     220         if name in props:
#     221             return props[name].__get__(instance)
# --> 222         raise AttributeError(
#     223             f"module {cls.__module__!r} has no attribute {name!r}")
#     224
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
#groupby the suburb and nearest school rank
# First grouping based on "SUBURB"
# Within each SUBURB we are grouping based on "NEAREST SCH RANK"
school_rank = housing_df.groupby(['SUBURB', 'NEAREST_SCH_RANK'])

# %%
school_rank.first()
# Out:
#                                                  ADDRESS   PRICE  BEDROOMS  \
# SUBURB            NEAREST_SCH_RANK
# Alexander Heights 46.0                    1 Cannon Court  530000         3
#                   75.0                    10 Karst Elbow  505000         4
#                   133.0                  14 Regent Drive  600000         4
# Alfred Cove       34.0              10 Clydesdale Street  855000         4
#                   61.0                 10 Lambert Street  867500         3
# ...                                                  ...     ...       ...
# Woodvale          77.0                 1 Parkwood Avenue  554500         3
#                   104.0                  14 Plumdale Way  500000         4
# Wooroloo          105.0                10 Clayden Street  358000         4
# Yokine            13.0                  1 Thurlow Avenue  525000         3
#                   65.0                   10 Fagan Street  505000         3
#
# ...

# %%
school_rank

# %%
# Using DataFrame.copy() create new DaraFrame.
school_rank2 = housing_df[['SUBURB', 'NEAREST_SCH_RANK']].copy()
school_rank2.head()
# Out:
#        SUBURB  NEAREST_SCH_RANK
# 0  South Lake               NaN
# 1       Wandi             129.0
# 2     Camillo             113.0
# 3    Bellevue               NaN
# 4   Lockridge               NaN

# %%
new_df = housing_df.filter(['SUBURB','NEAREST_SCH_RANK'], axis=1)

# %%
new_df
# Out:
#                 SUBURB  NEAREST_SCH_RANK
# 0           South Lake               NaN
# 1                Wandi             129.0
# 2              Camillo             113.0
# 3             Bellevue               NaN
# 4            Lockridge               NaN
# ...                ...               ...
# 33651  South Fremantle              49.0
# 33652      Westminster              35.0
# 33653      Westminster              35.0
# 33654       Girrawheen               NaN
# 33655          Midland              53.0
#
# [33656 rows x 2 columns]

# %%
#drop NaN values from each row 
new_df.dropna(subset=['NEAREST_SCH_RANK'])
# Out:
#                 SUBURB  NEAREST_SCH_RANK
# 1                Wandi             129.0
# 2              Camillo             113.0
# 9            Bayswater              29.0
# 11              Butler              39.0
# 13        Hammond Park             129.0
# ...                ...               ...
# 33650  South Fremantle             128.0
# 33651  South Fremantle              49.0
# 33652      Westminster              35.0
# 33653      Westminster              35.0
# 33655          Midland              53.0
#
# [22704 rows x 2 columns]

# %%
new_df

# %%
# # Create a bar chart based off of the group series from before
# rank_chart = school_rank.plot(kind='bar', figsize=(6,8))

# # Set the xlabel and ylabel using class methods
# rank_chart.set_xlabel("Suburb")
# rank_chart.set_ylabel("School Rank")

# plt.show()
# plt.tight_layout()

# %%
# Count how many times each school appears in a suburb
count_nearest_sch = nearest_sch['NEAREST_SCH'].count()

count_nearest_sch
# Out:
# SUBURB
# Alexander Heights    128
# Alfred Cove          120
# Alkimos              114
# Anketell              19
# Applecross            79
#                     ...
# Wooroloo              51
# Wungong               20
# Yanchep              118
# Yangebup             132
# Yokine                54
# Name: NEAREST_SCH, Length: 321, dtype: int64

# %%
top_10 = (housing_df['NEAREST_SCH'].value_counts()).iloc[:10]
top_10
# Out:
# SWAN VIEW SENIOR HIGH SCHOOL             895
# KIARA COLLEGE                            756
# ATWELL COLLEGE                           696
# JOSEPH BANKS SECONDARY COLLEGE           687
# SWAN VALLEY ANGLICAN COMMUNITY SCHOOL    567
# MUNDARING CHRISTIAN COLLEGE              552
# WANNEROO SECONDARY COLLEGE               550
# YOUTH FUTURES COMMUNITY SCHOOL           499
# COURT GRAMMAR SCHOOL                     488
# LAKE JOONDALUP BAPTIST COLLEGE           484
# Name: NEAREST_SCH, dtype: int64

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
count_nearest_sch.plot(kind="bar", figsize=(20,3.5))

# Set a title for the chart
plt.title("Number of schools in each suburb")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xn/zsfqtzcx4t9dbvmg4mq2kb640000gn/T/ipykernel_644/2126010931.py in <module>
#       3
#       4 # Set a title for the chart
# ----> 5 plt.title("Number of schools in each suburb")
#       6
#       7 plt.show()
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     220         if name in props:
#     221             return props[name].__get__(instance)
# --> 222         raise AttributeError(
#     223             f"module {cls.__module__!r} has no attribute {name!r}")
#     224
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
#count how many 'suburb' there are 
housing_df["SUBURB"].value_counts()
# Out:
# Bertram            231
# Iluka              212
# Bennett Springs    211
# Mindarie           209
# Carramar           208
#                   ...
# Munster              1
# Kwinana Beach        1
# Welshpool            1
# Wangara              1
# Naval Base           1
# Name: SUBURB, Length: 321, dtype: int64

# %% [markdown]
# ### Nearest School Dist

# %% [markdown]
# ### Nearest School Rank

# %%
housing_df.sort_values(by='NEAREST_SCH_RANK', ascending=True)
# Out:
#                    ADDRESS            SUBURB    PRICE  BEDROOMS  BATHROOMS  \
# 761      1/99 Roberts Road           Subiaco   450000         2          1
# 32516        9 Glen Street  West Leederville  1245000         4          2
# 33428  96 Kimberley Street  West Leederville  1510000         3          1
# 14850    26A Joseph Street  West Leederville  1100000         3          1
# 32938     9 Stubbs Terrace           Daglish   950000         2          1
# ...                    ...               ...      ...       ...        ...
# 33629       9A Simeon Rise          Pearsall   422500         4          2
# 33630     9a Sydenham Road        Doubleview   990000         4          2
# 33642    9B Longfield Road        Maddington   240000         3          1
# 33647      9B Shalford Way        Girrawheen   245000         3          1
# 33654      9D Shalford Way        Girrawheen   295000         3          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
#count how many different 'nearest sch rank' there are 
rank_count = housing_df["NEAREST_SCH_RANK"].sort_values().value_counts().rename_axis('SCH_RANK').to_frame('counts')
rank_count
# Out:
#           counts
# SCH_RANK
# 53.0         782
# 129.0        696
# 92.0         687
# 131.0        550
# 35.0         545
# ...          ...
# 55.0          23
# 71.0          23
# 88.0          22
# 5.0           10
# 15.0           8
#
# [103 rows x 1 columns]

# %%
rank_count_df = housing_df["NEAREST_SCH_RANK"].value_counts().rename_axis('SCH_RANK').to_frame('counts')
print (rank_count_df)
# Out:
#           counts
# SCH_RANK
# 53.0         782
# 129.0        696
# 92.0         687
# 131.0        550
# 35.0         545
# ...          ...
# 55.0          23
# 71.0          23
# 88.0          22
# 5.0           10
# 15.0           8
#
# [103 rows x 1 columns]

# %%
rank_count_df["SCH_RANK"].sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SCH_RANK'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
housing_df.drop(["ADDRESS", "NEAREST_SCH_RANK"], axis=1, inplace=True)

# %%
housing_df["GARAGE"].value_counts()
# Out:
# 2.0     20724
# 1.0      5290
# 3.0      2042
# 4.0      1949
# 6.0       466
# 5.0       362
# 8.0       129
# 7.0        97
# 12.0       30
# 10.0       26
# 9.0        17
# 14.0       13
# 13.0        8
# 11.0        7
# 16.0        4
# 18.0        3
# 20.0        3
# 32.0        1
# 17.0        1
# 21.0        1
# 99.0        1
# 26.0        1
# 22.0        1
# 50.0        1
# 31.0        1
# Name: GARAGE, dtype: int64

# %%
housing_df["GARAGE"] = housing_df["GARAGE"].fillna(housing_df["GARAGE"].mode()[0])
housing_df["BUILD_YEAR"] = housing_df["BUILD_YEAR"].fillna(housing_df["BUILD_YEAR"].mode()[0])

# %%
housing_df.PRICE = housing_df.PRICE.astype('int')
housing_df.BEDROOMS = housing_df.BEDROOMS.astype('int')
housing_df.BATHROOMS = housing_df.BATHROOMS.astype('int')
housing_df.GARAGE = housing_df.GARAGE.astype('int')
housing_df.LAND_AREA = housing_df.LAND_AREA.astype('int')
housing_df.FLOOR_AREA = housing_df.FLOOR_AREA.astype('int')
housing_df["DATE_SOLD"] = pd.to_datetime(housing_df["DATE_SOLD"])
housing_df["DATE_YEAR"] = housing_df["DATE_SOLD"].dt.year
housing_df["DATE_MONTH"] = housing_df["DATE_SOLD"].dt.month
housing_df.BUILD_YEAR= housing_df.BUILD_YEAR.astype('int')
housing_df.CBD_DIST= housing_df.CBD_DIST.astype('int')
housing_df.NEAREST_STN_DIST= housing_df.NEAREST_STN_DIST.astype('int')
housing_df.POSTCODE= housing_df.POSTCODE.astype('int')
housing_df.LATITUDE= housing_df.LATITUDE.astype('float')
housing_df.LONGITUDE= housing_df.LONGITUDE.astype('float')
housing_df.NEAREST_SCH_DIST= housing_df.NEAREST_SCH_DIST.astype('float')

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33656 entries, 0 to 33655
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBURB            33656 non-null  object
#  1   PRICE             33656 non-null  int32
#  2   BEDROOMS          33656 non-null  int32
#  3   BATHROOMS         33656 non-null  int32
#  4   GARAGE            33656 non-null  int32
#  5   LAND_AREA         33656 non-null  int32
#  6   FLOOR_AREA        33656 non-null  int32
#  7   BUILD_YEAR        33656 non-null  int32
#  8   CBD_DIST          33656 non-null  int32
#  9   NEAREST_STN       33656 non-null  object
#  10  NEAREST_STN_DIST  33656 non-null  int32
#  11  DATE_SOLD         33656 non-null  datetime64[ns]
#  12  POSTCODE          33656 non-null  int32
#  13  LATITUDE          33656 non-null  float64
#  14  LONGITUDE         33656 non-null  float64
#  15  NEAREST_SCH       33656 non-null  object
# ...

# %%
housing_df.drop(["DATE_SOLD"], axis=1, inplace=True)

# %%
housing_df.head()
# Out:
#        SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  FLOOR_AREA  \
# 0  South Lake  565000         4          2       2        600         160
# 1       Wandi  365000         3          2       2        351         139
# 2     Camillo  287000         3          1       1        719          86
# 3    Bellevue  255000         2          1       2        651          59
# 4   Lockridge  325000         4          1       2        466         131
#
#    BUILD_YEAR  CBD_DIST               NEAREST_STN  NEAREST_STN_DIST  POSTCODE  \
# 0        2003     18300  Cockburn Central Station              1800      6164
# 1        2013     26900           Kwinana Station              4900      6167
# 2        1979     22600           Challis Station              1900      6111
# 3        1953     17900           Midland Station              3600      6056
# 4        1998     11200        Bassendean Station              2000      6054
#
# ...

# %%
housing_df["DATE_YEAR"].value_counts()
# Out:
# 2018    5621
# 2019    5285
# 2020    5261
# 2017    4844
# 2016    3901
# 2015    3050
# 2014    1947
# 2013    1178
# 2012     615
# 2011     362
# 2010     271
# 2009     242
# 2007     143
# 2008     141
# 2006     133
# 2005     115
# 2003      86
# 2002      85
# 2004      74
# 2001      52
# 1998      41
# 2000      36
# 1999      32
# 1995      22
# 1997      22
# 1994      21
# 1996      17
# 1991      12
# 1993      12
# 1992      11
# 1988       9
# 1989       8
# 1990       7
# Name: DATE_YEAR, dtype: int64

# %%
clean_df = housing_df.copy()
clean_df.head(10)
# Out:
#          SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  FLOOR_AREA  \
# 0    South Lake  565000         4          2       2        600         160
# 1         Wandi  365000         3          2       2        351         139
# 2       Camillo  287000         3          1       1        719          86
# 3      Bellevue  255000         2          1       2        651          59
# 4     Lockridge  325000         4          1       2        466         131
# 5  Mount Richon  409000         4          2       1        759         118
# 6       Hilbert  400000         3          2       2        386         132
# 7       Waikiki  370000         4          2       2        468         158
# 8     Hamersley  565000         4          2       3        875         168
# 9     Bayswater  685000         3          2       8        552         126
#
#    BUILD_YEAR  CBD_DIST               NEAREST_STN  NEAREST_STN_DIST  POSTCODE  \
# ...
